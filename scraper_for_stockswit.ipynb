# %%
import requests
import urllib.request
import time, json, os, traceback
from json import JSONDecodeError
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
from time import sleep
from collections import deque
import pandas as pd
import glob

class StockTwitsAPIScraper:
    def __init__(self, symbol, date, maxId):
        self.symbol = symbol
        self.link = "https://api.stocktwits.com/api/2/streams/symbol/{}.json?".format(symbol)
        self.targetDate = date
        self.tweets = []
        self.reqeustQueue = deque()
        self.maxId = maxId
        self.initDir()

    def setLimits(self, size, duration):
        self.size = size
        self.duration = duration
        self.requestInterval = duration // size + 1 if duration % size else duration // size

    # create directions if they don't exist
    def initDir(self):
        if not os.path.isdir("stocks"):
            os.mkdir("stocks")
        if not os.path.isdir("stocks/{}".format(self.symbol)):
            os.mkdir("stocks/{}".format(self.symbol))

    # write tweets we get and the ID of the last tweet in case system break down
    def writeJson(self):
        if self.tweets:
            self.maxId = self.tweets[-1]["id"]
            fileName = "stocks/{}/{}.json".format(self.symbol, self.maxId)
            with open(fileName, "w") as f:
                json.dump(self.tweets, f)
    
    def getCurrentUrl(self):
        return self.link + "max={}".format(self.maxId)

    # request manager
    # can't exceed 200 requests within an hour
    def requestManager(self):
        if len(self.reqeustQueue) == self.size:
            now = datetime.now()
            firstRequest = self.reqeustQueue.popleft()
            if now < firstRequest + timedelta(seconds=self.duration):
                timeDiff = firstRequest - now
                waitTime = timeDiff.total_seconds() + 1 + self.duration                
                print("Reach request limit, wait for {} seconds.".format(waitTime))
                sleep(waitTime)

    def getMessages(self, url):
        self.requestManager()

        response = requests.get(url)
        self.reqeustQueue.append(datetime.now())
        try:
            data = json.loads(response.text)
        except JSONDecodeError:
            if "Bad Gateway" in response.text:
                print("Just a Bad Gateway, wait for 1 minute.")
                sleep(60)
                return True
            print(len(self.reqeustQueue))
            print(self.reqeustQueue[0], datetime.now())
            print(url)
            print(response.text)
            print(traceback.format_exc())
            raise Exception("Something worong with the response.")
        if data and data["response"]["status"] == 200:
            data["cursor"]["max"]
            for m in data["messages"]:
                record = {}            
                createdAt = datetime.strptime(m["created_at"], "%Y-%m-%dT%H:%M:%SZ")
                if createdAt < self.targetDate:
                    return False
                record["id"] = m["id"]
                record["text"] = m["body"]
                record["time"] = createdAt.timestamp()
                record["sentiment"] = m["entities"]["sentiment"]["basic"] if m["entities"]["sentiment"] else ""
                self.tweets.append(record)
        else:
            print(response.text)        
        return True

    def getTweetsAndWriteToFile(self):        
        if not self.getMessages(self.getCurrentUrl()):
            return False
        self.writeJson()
        print("Scrap {} tweets starting from {}.".format(len(self.tweets), self.maxId))
        self.tweets.clear()
        sleep(self.requestInterval)
        return True

    def scrapTweets(self):        
        try:
            doScrap = True
            while doScrap:
                doScrap = self.getTweetsAndWriteToFile()
        except Exception:
            print(traceback.format_exc())

symbol = input("Enter stock symbol: ")
print("This scraper scraps tweets backward.\n\
The ID you put in belongs the most recent tweet you're goint go scrap.\n\
And the scraper will keep going backward to scrap older tweets.")
maxId = input("Enter the starting tweet ID: ")
targetDate = input("Enter the earlest date (mmddyyyy): ")
print("You can only send 200 requests to StockTwits in an hour.")
requestLimit = input("Enter the limit of number of requests within an hour: ")

scraper = StockTwitsAPIScraper(symbol, datetime.strptime(targetDate, "%m%d%Y"), int(maxId))
scraper.setLimits(int(requestLimit), 3600)
scraper.scrapTweets()
# Out:
# Enter stock symbol: AAPL
# This scraper scraps tweets backward.
# The ID you put in belongs the most recent tweet you're goint go scrap.
# And the scraper will keep going backward to scrap older tweets.
# Enter the starting tweet ID: 232908259
# Enter the earlest date (mmddyyyy): 07012020
# You can only send 200 requests to StockTwits in an hour.
# Enter the limit of number of requests within an hour: 199
# Scrap 30 tweets starting from 232901943.
# Scrap 30 tweets starting from 232893386.
# Scrap 30 tweets starting from 232889201.
# Scrap 30 tweets starting from 232879091.
# Scrap 30 tweets starting from 232874580.
# Scrap 30 tweets starting from 232868686.
# Scrap 30 tweets starting from 232863840.
# Scrap 30 tweets starting from 232858622.
# Scrap 30 tweets starting from 232854072.
# Scrap 30 tweets starting from 232847987.
# Scrap 30 tweets starting from 232843385.
# Scrap 30 tweets starting from 232838988.
# Scrap 30 tweets starting from 232836590.
# Scrap 30 tweets starting from 232834496.
# Scrap 30 tweets starting from 232831352.
# Scrap 30 tweets starting from 232824463.
# Scrap 30 tweets starting from 232820225.
# Scrap 30 tweets starting from 232815690.
# Scrap 30 tweets starting from 232811927.
# Scrap 30 tweets starting from 232808406.
# Scrap 30 tweets starting from 232803885.
# Scrap 30 tweets starting from 232801302.
# Scrap 30 tweets starting from 232796626.
# Scrap 30 tweets starting from 232793556.
# Scrap 30 tweets starting from 232788673.
# Scrap 30 tweets starting from 232783619.
# Scrap 30 tweets starting from 232781208.
# Scrap 30 tweets starting from 232777291.
# Scrap 30 tweets starting from 232774733.
# Scrap 30 tweets starting from 232772108.
# Scrap 30 tweets starting from 232769819.
# Scrap 30 tweets starting from 232767409.
# Scrap 30 tweets starting from 232764308.
# Scrap 30 tweets starting from 232760821.
# Scrap 30 tweets starting from 232758812.
# Scrap 30 tweets starting from 232754258.
# Scrap 30 tweets starting from 232752078.
# Scrap 30 tweets starting from 232749696.
# Scrap 30 tweets starting from 232747343.
# Scrap 30 tweets starting from 232745181.
# Scrap 30 tweets starting from 232742426.
# Scrap 30 tweets starting from 232740092.
# Scrap 30 tweets starting from 232738031.
# Scrap 30 tweets starting from 232735790.
# Scrap 30 tweets starting from 232732776.
# Scrap 30 tweets starting from 232730979.
# Scrap 30 tweets starting from 232728881.
# Scrap 30 tweets starting from 232727347.
# Scrap 30 tweets starting from 232725790.
# Scrap 30 tweets starting from 232723936.
# Scrap 30 tweets starting from 232721815.
# Scrap 30 tweets starting from 232719571.
# Scrap 30 tweets starting from 232717611.
# Scrap 30 tweets starting from 232716105.
# Scrap 30 tweets starting from 232714368.
# Scrap 30 tweets starting from 232712553.
# Scrap 30 tweets starting from 232710638.
# Scrap 30 tweets starting from 232708792.
# Scrap 30 tweets starting from 232706994.
# Scrap 30 tweets starting from 232705533.
# Scrap 30 tweets starting from 232703546.
# Scrap 30 tweets starting from 232701621.
# Scrap 30 tweets starting from 232700137.
# Scrap 30 tweets starting from 232699234.
# Scrap 30 tweets starting from 232698231.
# Scrap 30 tweets starting from 232697313.
# Scrap 30 tweets starting from 232696088.
# Scrap 30 tweets starting from 232694980.
# Scrap 30 tweets starting from 232694170.
# Scrap 30 tweets starting from 232693435.
# Scrap 30 tweets starting from 232692581.
# Scrap 30 tweets starting from 232691885.
# Scrap 30 tweets starting from 232691341.
# Scrap 30 tweets starting from 232690724.
# Scrap 30 tweets starting from 232690203.
# Scrap 30 tweets starting from 232689622.
# Scrap 30 tweets starting from 232689057.
# Scrap 30 tweets starting from 232688646.
# Scrap 30 tweets starting from 232688020.
# Scrap 30 tweets starting from 232687180.
# Scrap 30 tweets starting from 232686379.
# Scrap 30 tweets starting from 232685376.
# Scrap 30 tweets starting from 232684874.
# Scrap 30 tweets starting from 232684100.
# Scrap 30 tweets starting from 232683287.
# Scrap 30 tweets starting from 232682661.
# Scrap 30 tweets starting from 232681794.
# Scrap 30 tweets starting from 232681190.
# Scrap 30 tweets starting from 232680711.
# Scrap 30 tweets starting from 232679695.
# Scrap 30 tweets starting from 232678987.
# Scrap 30 tweets starting from 232678422.
# Scrap 30 tweets starting from 232677862.
# Scrap 30 tweets starting from 232677006.
# Scrap 30 tweets starting from 232676067.
# Scrap 30 tweets starting from 232674545.
# Scrap 30 tweets starting from 232673448.
# Scrap 30 tweets starting from 232672607.
# Scrap 30 tweets starting from 232671493.
# Scrap 30 tweets starting from 232670109.
# Scrap 30 tweets starting from 232669076.
# Scrap 30 tweets starting from 232667061.
# Scrap 30 tweets starting from 232665769.
# Scrap 30 tweets starting from 232663837.
# Scrap 30 tweets starting from 232661372.
# Scrap 30 tweets starting from 232657988.
# Scrap 30 tweets starting from 232654799.
# Scrap 30 tweets starting from 232652607.
# Scrap 30 tweets starting from 232650584.
# Scrap 30 tweets starting from 232648756.
# Scrap 30 tweets starting from 232646246.
# Scrap 30 tweets starting from 232643581.
# Scrap 30 tweets starting from 232640299.
# Scrap 30 tweets starting from 232634883.
# Scrap 30 tweets starting from 232629341.
# Scrap 30 tweets starting from 232626645.
# Scrap 30 tweets starting from 232623837.
# Scrap 30 tweets starting from 232620536.
# Scrap 30 tweets starting from 232617126.
# Scrap 30 tweets starting from 232612754.
# Scrap 30 tweets starting from 232608054.
# Scrap 30 tweets starting from 232603538.
# Scrap 30 tweets starting from 232599427.
# Scrap 30 tweets starting from 232596558.
# Scrap 30 tweets starting from 232592397.
# Scrap 30 tweets starting from 232587590.
# Scrap 30 tweets starting from 232585023.
# Scrap 30 tweets starting from 232582474.
# Scrap 30 tweets starting from 232579498.
# Scrap 30 tweets starting from 232575520.
# Scrap 30 tweets starting from 232572845.
# Scrap 30 tweets starting from 232570133.
# Scrap 30 tweets starting from 232567036.
# Scrap 30 tweets starting from 232562926.
# Scrap 30 tweets starting from 232558536.
# Scrap 30 tweets starting from 232553687.
# Scrap 30 tweets starting from 232550360.
# Scrap 30 tweets starting from 232545588.
# Scrap 30 tweets starting from 232543399.
# Scrap 30 tweets starting from 232540588.
# Scrap 30 tweets starting from 232537577.
# Scrap 30 tweets starting from 232534414.
# Scrap 30 tweets starting from 232531364.
# Scrap 30 tweets starting from 232529430.
# Scrap 30 tweets starting from 232527169.
# Scrap 30 tweets starting from 232524260.
# Scrap 30 tweets starting from 232521599.
# Scrap 30 tweets starting from 232518220.
# Scrap 30 tweets starting from 232514677.
# Scrap 30 tweets starting from 232511324.
# Scrap 30 tweets starting from 232507605.
# Scrap 30 tweets starting from 232504982.
# Scrap 30 tweets starting from 232502972.
# Scrap 30 tweets starting from 232500993.
# Scrap 30 tweets starting from 232498982.
# Scrap 30 tweets starting from 232496517.
# Scrap 30 tweets starting from 232494604.
# Scrap 30 tweets starting from 232492887.
# Scrap 30 tweets starting from 232490637.
# Scrap 30 tweets starting from 232488658.
# Scrap 30 tweets starting from 232486907.
# Scrap 30 tweets starting from 232485100.
# Scrap 30 tweets starting from 232483084.
# Scrap 30 tweets starting from 232479620.
# Scrap 30 tweets starting from 232476918.
# Scrap 30 tweets starting from 232474425.
# Scrap 30 tweets starting from 232471942.
# Scrap 30 tweets starting from 232467443.
# Scrap 30 tweets starting from 232464752.
# Scrap 30 tweets starting from 232462906.
# Scrap 30 tweets starting from 232459984.
# Scrap 30 tweets starting from 232457104.
# Scrap 30 tweets starting from 232454434.
# Scrap 30 tweets starting from 232451414.
# Scrap 30 tweets starting from 232448687.
# Scrap 30 tweets starting from 232445955.
# Scrap 30 tweets starting from 232442373.
# Scrap 30 tweets starting from 232440221.
# Scrap 30 tweets starting from 232438882.
# Scrap 30 tweets starting from 232437122.
# Scrap 30 tweets starting from 232435139.
# Scrap 30 tweets starting from 232432307.
# Scrap 30 tweets starting from 232430289.
# Scrap 30 tweets starting from 232427991.
# Scrap 30 tweets starting from 232426098.
# Scrap 30 tweets starting from 232423992.
# Scrap 30 tweets starting from 232421613.
# Scrap 30 tweets starting from 232419445.
# Scrap 30 tweets starting from 232417197.
# Scrap 30 tweets starting from 232414846.
# Scrap 30 tweets starting from 232413311.
# Scrap 30 tweets starting from 232411676.
# Scrap 30 tweets starting from 232408875.
# Scrap 30 tweets starting from 232407013.
# Scrap 30 tweets starting from 232405386.
# Scrap 30 tweets starting from 232403206.
# Scrap 30 tweets starting from 232401812.
# Scrap 30 tweets starting from 232400383.
# Scrap 30 tweets starting from 232398868.
# Scrap 30 tweets starting from 232396939.
# Scrap 30 tweets starting from 232394571.
# Scrap 30 tweets starting from 232392958.
# Scrap 30 tweets starting from 232390587.
# Scrap 30 tweets starting from 232387389.
# Scrap 30 tweets starting from 232385461.
# Scrap 30 tweets starting from 232383884.
# Scrap 30 tweets starting from 232381831.
# Scrap 30 tweets starting from 232380371.
# Scrap 30 tweets starting from 232379134.
# Scrap 30 tweets starting from 232377864.
# Scrap 30 tweets starting from 232376452.
# Scrap 30 tweets starting from 232374960.
# Scrap 30 tweets starting from 232373816.
# Scrap 30 tweets starting from 232372602.
# Scrap 30 tweets starting from 232371258.
# Scrap 30 tweets starting from 232370216.
# Scrap 30 tweets starting from 232368967.
# Scrap 30 tweets starting from 232367859.
# Scrap 30 tweets starting from 232366667.
# Scrap 30 tweets starting from 232365461.
# Scrap 30 tweets starting from 232364365.
# Scrap 30 tweets starting from 232363438.
# Scrap 30 tweets starting from 232362659.
# Scrap 30 tweets starting from 232361520.
# Scrap 30 tweets starting from 232360626.
# Scrap 30 tweets starting from 232359839.
# Scrap 30 tweets starting from 232359032.
# Scrap 30 tweets starting from 232358244.
# Scrap 30 tweets starting from 232357304.
# Scrap 30 tweets starting from 232356602.
# Scrap 30 tweets starting from 232355539.
# Scrap 30 tweets starting from 232354763.
# Scrap 30 tweets starting from 232354138.
# Scrap 30 tweets starting from 232353262.
# Scrap 30 tweets starting from 232352610.
# Scrap 30 tweets starting from 232351981.
# Scrap 30 tweets starting from 232351412.
# Scrap 30 tweets starting from 232350654.
# Scrap 30 tweets starting from 232350068.
# Scrap 30 tweets starting from 232349436.
# Scrap 30 tweets starting from 232348829.
# Scrap 30 tweets starting from 232348379.
# Scrap 30 tweets starting from 232347966.
# Scrap 30 tweets starting from 232347469.
# Scrap 30 tweets starting from 232346898.
# Scrap 30 tweets starting from 232346404.
# Scrap 30 tweets starting from 232346001.
# Scrap 30 tweets starting from 232345625.
# Scrap 30 tweets starting from 232345289.
# Scrap 30 tweets starting from 232344826.
# Scrap 30 tweets starting from 232344557.
# Scrap 30 tweets starting from 232344302.
# Scrap 30 tweets starting from 232344011.
# Scrap 30 tweets starting from 232343767.
# Scrap 30 tweets starting from 232343553.
# Scrap 30 tweets starting from 232343263.
# -----------------------------------------------------
# KeyboardInterrupt   Traceback (most recent call last)
# <ipython-input-41-2d2456d4461d> in <module>
#     117 scraper = StockTwitsAPIScraper(symbol, datetime.strptime(targetDate, "%m%d%Y"), int(maxId))
#     118 scraper.setLimits(int(requestLimit), 3600)
# --> 119 scraper.scrapTweets()
#
# <ipython-input-41-2d2456d4461d> in scrapTweets(self)
#     102             doScrap = True
#     103             while doScrap:
# --> 104                 doScrap = self.getTweetsAndWriteToFile()
#     105         except Exception:
#     106             print(traceback.format_exc())
#
# <ipython-input-41-2d2456d4461d> in getTweetsAndWriteToFile(self)
#      95         print("Scrap {} tweets starting from {}.".format(len(self.tweets), self.maxId))
#      96         self.tweets.clear()
# ---> 97         sleep(self.requestInterval)
#      98         return True
#      99
#
# KeyboardInterrupt:

# %%
def merge(symbol):
    '''
    input all .json files 
    merge them into one df
    '''
    path = r'/Users/hau/Desktop/Text_group_project/stock-twits-scraper-master/stocks/' # use the path where .json are saved
    all_files = glob.glob(path + symbol + "/*.json")

    dfs = [] 
    for file in all_files:
        data = pd.read_json(file) 
        dfs.append(data) 
    temp = pd.concat(dfs, ignore_index=True)
    temp['time'] = pd.to_datetime(temp.time, unit = 's') - timedelta(hours = 20)
    
    return temp

# %%
aapl = merge('AAPL')
aapl.sort_values(by = 'time')
#aapl.to_csv("aapl.csv")
# Out:
#                id                                               text  \
# 140186  232343263                              $AAPL reverse split?!
# 140185  232343281               $aapl 4 for 1 stock split jesussssss
# 140184  232343295  $AAPL 4;1 stock split .. that would pop it ano...
# 140183  232343310                       $AMZN $AAPL with a 4-1 split
# 140182  232343313                               $AAPL FUUUUUUUCK YES
# ...           ...                                                ...
# 164067  249505699  $HPQ $DELL $AAPL Lenovo, HP, and Dell led PCs ...
# 164068  249505698                $AAPL going to be great going into📱
# 164066  249505858  $AAPL any likelihood appl heads to 95 after ea...
# 164065  249505977  $AAPL NEW ARTICLE : 2 Top Growth Stocks You Ca...
# 164064  249506024                        $SPY \n$gld \n$aapl \n$nbrv
#
#                       time sentiment
# 140186 2020-07-30 04:33:15
# 140185 2020-07-30 04:33:17
# 140184 2020-07-30 04:33:19
# 140183 2020-07-30 04:33:21
# 140182 2020-07-30 04:33:21
# ...                    ...       ...
# 164067 2020-10-10 01:32:49
# 164068 2020-10-10 01:32:49
# 164066 2020-10-10 01:35:25
# 164065 2020-10-10 01:37:17
# 164064 2020-10-10 01:38:00
#
# [190043 rows x 4 columns]

# %%
amzn = merge('AMZN') #240702326
amzn.sort_values(by = 'time')
#amzn.to_csv("amzn.csv")
# Out:
#               id                                               text  \
# 7258   240702326                               $AMZN As I said 100%
# 7257   240702737        $AMZN c&#39;mon sluggo bezos  do something!
# 7256   240702757  $CRWD $ZM at $120b cap, CRWD at $27b cap. this...
# 7255   240703095  $SPY At some point you have to let go of what ...
# 7254   240703184  $AMZN nice after hour gains, tomorrow we take ...
# ...          ...                                                ...
# 25353  249332682  $AMD in out.  Just bought $AMZN Calls.  At lea...
# 25352  249333068  $AMZN up $36.00 from next suggested buy entry ...
# 25351  249333217                        $AMZN no more tweets please
# 25350  249333592                 $AMZN at least today, this applies
# 25349  249333682  $SPY $AAPL $AMZN  the only manipulation going ...
#
#                      time sentiment
# 7258  2020-08-31 09:18:53
# 7257  2020-08-31 09:21:22   Bullish
# 7256  2020-08-31 09:21:30   Bullish
# 7255  2020-08-31 09:23:33
# 7254  2020-08-31 09:24:07
# ...                   ...       ...
# 25353 2020-10-09 00:01:11   Bearish
# 25352 2020-10-09 00:02:15   Bullish
# 25351 2020-10-09 00:02:40   Bullish
# 25350 2020-10-09 00:03:44   Bullish
# 25349 2020-10-09 00:03:58   Bullish
#
# [26189 rows x 4 columns]

# %%
fb = merge('FB') 
fb.sort_values(by = 'time')
#amzn.to_csv("amzn.csv")
# Out:
#              id                                               text  \
# 2969  244555857  $FB OMG.. Seriously People.. KIM KARDASHIAN **...
# 2968  244556226  $fb $aapl $msft $crm most people are beting on...
# 2967  244556378  $FB Glad I sold at 268. Will buy again tomorro...
# 2966  244556599        $FB 242 worst case-but I bought here at 251
# 2965  244557191  $FB Fakebook has been a source of “discord” wi...
# ...         ...                                                ...
# 424   249725015                         $FB wow what a chart today
# 423   249726548                     $FB $325 eow, Mark this post 👌
# 422   249726708    $FB hopefully this will be a multi day rally...
# 421   249726882  $FB Facebook reverses stance on Holocaust deni...
# 420   249727098                                        $FB is very
#
#                     time sentiment
# 2969 2020-09-17 03:27:38   Bullish
# 2968 2020-09-17 03:28:55
# 2967 2020-09-17 03:29:23
# 2966 2020-09-17 03:30:07   Bullish
# 2965 2020-09-17 03:32:02   Bearish
# ...                  ...       ...
# 424  2020-10-12 00:52:09
# 423  2020-10-12 00:57:26   Bullish
# 422  2020-10-12 00:57:56   Bullish
# 421  2020-10-12 00:58:33
# 420  2020-10-12 00:59:20   Bullish
#
# [5339 rows x 4 columns]
